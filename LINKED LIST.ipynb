# %% [markdown]
#
#     BY SELF

# %%
class LL:
    def __init__(self,data):
        self.data=data
        self.next=None
        
def inputLL():
    list=[int(i) for i in input().split()]
    head=None
    for current in list:
        if current==-1:
            break
        
        newnode=LL(current)
        if head==None:
            head=newnode
            
        else:
            curr=head
            while curr.next is not None:
                curr=curr.next
                
            curr.next=newnode
    return head
        
def printLL(head):
    while head is not None:
        print(str(head.data)+'->',end=" ")
        head=head.next
    
    print('None')
    
def lenLL(head):
    l=0
    while head is not None:
        l+=1
        head=head.next
        
    return l

def insertLL(head,i,data):
    if i<0 and i>len(head):
        return head
    j=0
    prev=None
    curr=head
    while j<i:
        prev=curr
        curr=curr.next
        j+=1
    newnode=LL(data)
    if prev is not None:
        prev.next=newnode
    else:
        head=newnode
    newnode.next=curr
    
    return head

def deleteLL(head,i):
    j=0
    prev=None
    curr=head
    while j<i:
        prev=curr
        curr=curr.next
        j+=1
        if j==i:
            if curr is not None:
                prev.next=curr.next
            else:
                prev.next=None
    if prev==None:
        head=head.next
    
    return head

def reverseLL(head):
    if head is None or head.next is None:
        return head,head
    smallhead,smalltail=reverseLL(head.next)
    smalltail.next=head
    head.next=None
    return smallhead,head

def reverseLL2(head):
    if head is None or head.next is None:
        return head
    smallhead=reverseLL2(head.next)
    tail=head.next
    tail.next=head
    head.next=None
    return smallhead

def reverseLLi(head):
    curr=head
    prev=None
    while curr is not None:
                
        nextt=curr.next
        curr.next=prev
        prev=curr
        curr=nextt
    return prev

def midLL(head):
    x=lenL(head)//2
    if x%2!=0:
        for i in range(x):
            head= head.next
    else:
        for i in range(x-1):
            head=head.next
    return head.data

def midLL2(head):
    slow=head
    fast=head
    while fast.next!=None and fast.next.next!=None:
        slow=slow.next
        fast=fast.next.next
    return slow.data

def mergeLL(h1,h2):
    head=None
    tail=None
    
    if h1.data<h2.data:
        head=h1
        tail=h1
        h1=h1.next
        
    else:
        head=h2
        tail=h2
        h2=h2.next
    while h1!=None and h2!=None:
        if h1.data<h2.data:
            tail.next=h1
            h1=h1.next
            tail=tail.next
        
        else:
            tail.next=h2
            h2=h2.next
            tail=tail.next
    if h1==None:
        while h2 is not None:
            tail.next=h2
            h2=h2.next
            tail=tail.next
    else:
        while h1 is not None:
            tail.next=h1
            h1=h1.next
            tail=tail.next
            
    return head

def findLL(head,i): # Assignment    FIND THE INTEGER IN THE LL

    j=0
    while head is not None:
        if head.data==i:
            break
        else:
            head=head.next
            j+=1
    if head.data!=i:
        return -1
    return j
        
def appendlastLL(head,n): #AppendLastNToFirst
    y=lenLL(head)
    
    tail=head
    while tail.next is not None:
        tail=tail.next
    for i in range(y-n):
        curr=head
        print('a')
        tail.next=curr
        print(tail.next.data)
        tail=tail.next
        print(tail.data)
        tail.next=None
        
        head=head.next
        print(head.data)
    return head
    
def mergesortLL(head):
    x=lenL(head)//2

# %% [markdown]
#
#     Assignment
#     FIND THE INTEGER IN THE LL

# %%
x=int(input())
lst=[]
lst1=[]
for i in range(x):
#     y=chr(ord(A)+i)
    y=inputLL()
    z=int(input())
    lst.append(y)
    lst1.append(z)

for i in range(x):
    m=appendlastLL(lst[i],lst1[i])
    printLL(m)
# Out:
# 1
# 1 2 3 4 5 6
# 3
# a
# 1
# 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 12
#       9     lst1.append(z)
#      11 for i in range(x):
# ---> 12     m=appendlastLL(lst[i],lst1[i])
#      13     printLL(m)
#
# Cell In[54], line 188, in appendlastLL(head, n)
#     185     tail.next=None
#     187     head=head.next
# --> 188     print(head.data)
#     189 return head
#
# AttributeError: 'NoneType' object has no attribute 'data'
